# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import numpy as np

#data = np.genfromtxt('../data/Paleotopography_bathymetry/Golonka_rev210/000Ma_Golonka.xyz')
#data = np.genfromtxt('../data/Golonka_Smoothed/10Ma_Golonka.xyz')
data = np.genfromtxt('paleotopo_grids/paleotopo_7.00Ma.xyz')
x = data[:,0]
y = data[:,1]
z = data[:,2]

plt.figure(figsize=(15, 8))

m = Basemap(llcrnrlon=-180,llcrnrlat=-90,urcrnrlon=180,urcrnrlat=90,projection='kav7', lon_0=0)    
xi, yi = m(x, y)
cs = m.scatter(xi, yi, marker='.', c=z, alpha=0.5, lw=0,)

m.drawparallels(np.arange(-90., 90., 10.), labels=[1,0,0,0], fontsize=10)
m.drawmeridians(np.arange(-180., 180., 45.), labels=[0,0,0,1], fontsize=10)
#m.drawcoastlines()   

cbar = m.colorbar(cs, location='bottom', pad="10%")
plt.title("topography")
plt.show()
plt.close()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import numpy as np
import math, os

for t in range(7,8):
    os.system('gmt grd2xyz paleotopo_{0}.00Ma.nc | gmt surface -Rd -I1 -Gpaleotopo_{0}.00Ma_new.nc'.format(t))
    os.system('gmt grd2xyz paleotopo_{0}.00Ma_new.nc > paleotopo_{0}.00Ma.xyz'.format(t))

# %% [markdown]
# gmt grd2xyz paleotopo_7.00Ma.nc | gmt surface -Rd -I1 -Gnew.grd
